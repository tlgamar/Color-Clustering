# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img = cv2.imread('rgb01.png')
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = img.reshape((img.shape[1] * img.shape[0], 3))

# %%
kmeans = KMeans(n_clusters=5)
s = kmeans.fit(img)

# %%
labels = kmeans.labels_
print(labels)
labels = list(labels)
# Out:
# [0 0 0 ... 0 0 0]

# %%
centroid = kmeans.cluster_centers_
print(centroid)
# Out:
# [[254.74414173 254.76774194 254.73157279]
#  [254.67325994   0.47225999   0.47225999]
#  [  1.03335228 254.62241553   1.03335228]
#  [  0.39032998   0.39032998 254.69790012]
#  [195.07892004 187.3748702  196.80581516]]

# %%
percent = []
for i in range(len(centroid)):
    j = labels.count(i)
    j = j/(len(labels))
    percent.append(j)
print(percent)
# Out:
# [0.3014895589776667, 0.22979319519471095, 0.23056921712488915, 0.22845279367894863, 0.009695235023784568]

# %%
plt.pie(percent, colors = np.array(centroid/255), labels = np.arange(len(centroid)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
md = []
for i in range(1,21):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(img)
    o=kmeans.inertia_
    md.append(o)
print(md)
# Out:
# [4756726721.728655, 2964753630.0079703, 1492737714.8209403, 23997049.70909781, 15201276.455348734, 9790042.76033917, 6664664.528302704, 5216626.242644952, 4331485.369234265, 3664110.9166646865, 3248460.763667156, 2835933.0286349575, 2478106.7171033584, 2148757.0688547646, 1825948.4147268217, 1527858.4087720606, 1326586.4166023138, 1158881.1321422907, 1057932.0588556754, 992153.5987564427]

# %%
plt.plot(list(np.arange(1,21)), md)
plt.show()
