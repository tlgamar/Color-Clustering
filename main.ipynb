# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img = cv2.imread('b.jpg')
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = img.reshape((img.shape[1] * img.shape[0], 3))

# %%
md = []
for i in range(1,10):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(img)
    o=kmeans.inertia_
    md.append(o)
print(md)
# Out:
# [14834463756.595312, 2895088292.1593127, 1488290217.7974713, 619204791.4206142, 357724451.7353503, 149904309.39582315, 43100796.55873418, 30913417.122816946, 27729088.440168846]

# %%
plt.plot(list(np.arange(1,10)), md)
plt.show()

# %%
kmeans=KMeans(n_clusters=2)
s=kmeans.fit(img)
labels=kmeans.labels_
centroid=kmeans.cluster_centers_
labels=list(labels)
percent=[]
for i in range(len(centroid)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()
